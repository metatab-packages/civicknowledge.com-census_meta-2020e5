# %%
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline

mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package()
pkg
# Out:
# # Metadata for the 2020 ACS
# `civicknowledge.com-census_meta-2020e5-3.3.1` Last Update: 2023-04-22T00:23:32
#
# _Deatilsed metadata for ACS releases._
#
#
#
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * **[metadata](data/metadata.csv)**. Combined columns and tables
# * **[tables](data/tables.csv)**.
# * **[columns](data/columns.csv)**.

# %%
mdf = pkg.resource('metadata').dataframe()

# %%
mdf.head()
# Out:
#   table_id       title group_id  bare_title          universe  subject  \
# 0   B01001  Sex By Age   G01001  Population  Total population  Age-Sex
# 1   B01001  Sex By Age   G01001  Population  Total population  Age-Sex
# 2   B01001  Sex By Age   G01001  Population  Total population  Age-Sex
# 3   B01001  Sex By Age   G01001  Population  Total population  Age-Sex
# 4   B01001  Sex By Age   G01001  Population  Total population  Age-Sex
#
#     column_id            name                        path filtered_path  ...  \
# 0  B01001_001           Total                      /total           NaN  ...
# 1  B01001_002            Male                 /total/male           NaN  ...
# 2  B01001_003   Under 5 years   /total/male/under 5 years           NaN  ...
# 3  B01001_004    5 to 9 years    /total/male/5 to 9 years           NaN  ...
# 4  B01001_005  10 to 14 years  /total/male/10 to 14 years           NaN  ...
#
#   family household grand_pc opposite_sex group_quarters housing tenure  \
# 0    all       all      all          all            all     all    all
# 1    all       all      all          all            all     all    all
# 2    all       all      all          all            all     all    all
# 3    all       all      all          all            all     all    all
# 4    all       all      all          all            all     all    all
#
#   citizen foreign_born military
# 0     all          all      all
# 1     all          all      all
# 2     all          all      all
# 3     all          all      all
# 4     all          all      all
#
# [5 rows x 30 columns]

# %%
# Out:
# (True, False)

# %%
def is_nan(v):
    from math import isnan
    try:
        return isnan(v)
    except TypeError:
        return False
    
def age(v):
    if v == 'all':
        return v
    l, h = v.split('-')
    return f"ages {int(l)} to  {int(h)} years"

def path(v):
    if is_nan(v):
        return 'all'
    
    return ', '.join(v.strip('/').split('/'))

def poverty(v):
    if v == 'all':
        return v
    
    return 'poverty ratio '+v

def description(r):
    
    vals = [r.sex, r.raceeth, age(r.age), poverty(r.poverty_status), path(r.path) ]
    
    vals = [e for e in vals if e != 'all']
    
    return  r.title+" for " +r.universe+", "+', '.join(vals)
# Out:
#       table_id                                              title  \
# 0       B01001                                         Sex By Age
# 1       B01001                                         Sex By Age
# 2       B01001                                         Sex By Age
# 3       B01001                                         Sex By Age
# 4       B01001                                         Sex By Age
# ...        ...                                                ...
# 27845   B99283  Allocation Of Household Internet Subscription ...
# 27846   B99283  Allocation Of Household Internet Subscription ...
# 27847   B99283  Allocation Of Household Internet Subscription ...
# 27848   B99283  Allocation Of Household Internet Subscription ...
# 27849   B99283  Allocation Of Household Internet Subscription ...
#
#                                               bare_title  \
# 0                                             Sex By Age
# 1                                             Sex By Age
# 2                                             Sex By Age
# 3                                             Sex By Age
# 4                                             Sex By Age
# ...                                                  ...
# 27845  Allocation Of Household Internet Subscription ...
# 27846  Allocation Of Household Internet Subscription ...
# 27847  Allocation Of Household Internet Subscription ...
# 27848  Allocation Of Household Internet Subscription ...
# 27849  Allocation Of Household Internet Subscription ...
#
#                                           stripped_title          universe  \
# 0                                             Sex By Age  Total population
# 1                                             Sex By Age  Total population
# 2                                             Sex By Age  Total population
# 3                                             Sex By Age  Total population
# 4                                             Sex By Age  Total population
# ...                                                  ...               ...
# 27845  Allocation Of Household Internet Subscription ...        Households
# 27846  Allocation Of Household Internet Subscription ...        Households
# 27847  Allocation Of Household Internet Subscription ...        Households
# 27848  Allocation Of Household Internet Subscription ...        Households
# 27849  Allocation Of Household Internet Subscription ...        Households
#
#            subject table_raceeth table_age table_sex   column_id  \
# 0          Age-Sex           all       all       all  B01001_001
# 1          Age-Sex           all       all       all  B01001_002
# 2          Age-Sex           all       all       all  B01001_003
# 3          Age-Sex           all       all       all  B01001_004
# 4          Age-Sex           all       all       all  B01001_005
# ...            ...           ...       ...       ...         ...
# 27845  Imputations           all       all       all  B99283_001
# 27846  Imputations           all       all       all  B99283_002
# 27847  Imputations           all       all       all  B99283_003
# 27848  Imputations           all       all       all  B99283_004
# 27849  Imputations           all       all       all  B99283_005
#
#                                                     name   sex raceeth  \
# 0                                                  Total   all     all
# 1                                                   Male  male     all
# 2                                          Under 5 years  male     all
# 3                                           5 to 9 years  male     all
# 4                                         10 to 14 years  male     all
# ...                                                  ...   ...     ...
# 27845                                              Total   all     all
# 27846                                            Dial-up   all     all
# 27847  Broadband such as cable, fiberoptic, or DSL, s...   all     all
# 27848                                 Cellular data plan   all     all
# 27849                                      Not allocated   all     all
#
#            age poverty_status  \
# 0          all            all
# 1          all            all
# 2      000-005            all
# 3      005-009            all
# 4      010-014            all
# ...        ...            ...
# 27845      all            all
# 27846      all            all
# 27847      all            all
# 27848      all            all
# 27849      all            all
#
#                                                     path
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 27845                                                NaN
# 27846                                 /allocated/dial-up
# 27847  /allocated/broadband such as cable, fiberoptic...
# 27848                      /allocated/cellular data plan
# 27849                                     /not allocated
#
# [27850 rows x 16 columns]
